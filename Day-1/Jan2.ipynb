# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv("mldata1.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
plt.scatter(df.area,df.price,color="red",marker="+")
plt.xlabel("area(in sq ft)")
plt.ylabel("price(US Dollar)")
plt.plot(df['area'], reg.predict(df[['area']]), color="blue", label="Linear Regression")

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %% [raw]
# predicted_price = reg.predict([[3300]])
# print(predicted_price)

# %%
print("Model Coefficients:", reg.coef_)
print("Model Intercept:", reg.intercept_)
predicted_price = reg.predict([[3300]])
print("Predicted Price:", predicted_price)
# Out:
# Model Coefficients: [135.78767123]
# Model Intercept: 180616.43835616432
# Predicted Price: [628715.75342466]
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

# %%
d=pd.read_csv("ml2.csv");
d
# Out:
#    area
# 0  3000
# 1  3200
# 2  3600
# 3  4000
# 4  4500
# 5  5000
# 6  5100

# %%
p=reg.predict(d)

# %%
print(p)
# Out:
# [587979.45205479 615136.98630137 669452.05479452 723767.12328767
#  791660.95890411 859554.79452055 873133.56164384]
